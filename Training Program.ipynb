# %% [markdown]
# # training model for color scale H&E

# %%
# !python train.py --dataroot ./dataset --name SNRGAN_test --model cycle_gan --gpu_ids -1

# %% [markdown]
# # testing model for color scale H&E

# %%
# !python test.py --dataroot ./dataset/maps/OCT2HE_label --name SNRGAN_fullsize --model cycle_gan
# Out:
# Traceback (most recent call last):
#   File "C:\Users\tommy\NTU\Medical AI code\unsupervised SNRGAN\test.py", line 23, in <module>
#     from options.test_options import TestOptions
#   File "C:\Users\tommy\NTU\Medical AI code\unsupervised SNRGAN\options\test_options.py", line 1, in <module>
#     from .base_options import BaseOptions
#   File "C:\Users\tommy\NTU\Medical AI code\unsupervised SNRGAN\options\base_options.py", line 3, in <module>
#     from util import util
#   File "C:\Users\tommy\NTU\Medical AI code\unsupervised SNRGAN\util\util.py", line 3, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'

# %%
# !python test.py --dataroot "./datasets/maps/3Ddata" --name SNRGAN_non --model cycle_gan
# Out:
# ...
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/maps/3Ddata        	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 3
#                      name: SNRGAN_non                    	[default: experiment_name]
# ...
